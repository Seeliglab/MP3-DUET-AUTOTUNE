# %%
import os
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
import math
import matplotlib.patches as patches

# %%
# %matplotlib inline

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)

# %% [markdown]
# # Load data

# %% [markdown]
# # Woolfson

# %%
KD_BN3_AN3 = 3100 #nM
KD_BN3_AN35 = 279 #nM
KD_BN3_AN4 = 75 #nM

KD_BN35_AN3 = 640 #nM
KD_BN35_AN35 = 5.15 #nM
KD_BN35_AN4 = 0.2 #nM

KD_BN4_AN3 = 387 #nM
KD_BN4_AN35 = 0.47 #nM
KD_BN4_AN4 = 0.1 #nM

# %%
Woolfson_df = pd.DataFrame([[3100, 279, 75], [640, 5.15, 0.2], [387, 0.47, 0.1]])

# %%
Woolfson_df.columns = ["AN3", "AN35", "AN4"]

# %%
Woolfson_df.index = ["BN3", "BN35", "BN4"]

# %%
Woolfson_df
# Out:
#        AN3    AN35   AN4
# BN3   3100  279.00  75.0
# BN35   640    5.15   0.2
# BN4    387    0.47   0.1

# %%
Woolfson_log_df = np.log(Woolfson_df)

# %%
plt.figure(figsize=(4.0, 3.0), dpi=100)


result = sns.heatmap(Woolfson_df, cmap=cmap)

ax = result.axes

#plt.xlabel('Activation domain', size = 12)
#plt.ylabel('Binding domain', size = 12)

# %%
plt.figure(figsize=(4.0, 3.0), dpi=100)


result = sns.heatmap(Woolfson_log_df, cmap=cmap)

ax = result.axes

# %%
plt.figure(figsize=(4.0, 3.0), dpi=100)


result = sns.heatmap( Woolfson_log_df, cmap=cmap, mask=np.triu(np.ones_like(Woolfson_df)) )

# %% [markdown]
# ## TRP sample (input - before selecting for interaction)

# %%
trp_df = pd.read_csv('L68-TRP-Reads-NO-PUMAs.csv', index_col=0)

# %%
trp_df.shape
# Out:
# (28, 28)

# %%
trp_df
# Out:
#                 N1       N2       N5       N6       N7       N8      P5A  \
# Binder
# N1            21.0   2025.0   2026.0   1201.0   1710.0   2704.0   1677.0
# N2          1714.0    694.0  10890.0   8146.0   6883.0   7260.0   6012.0
# N5          2183.0   8765.0   1172.0   1937.0   6874.0   7233.0   8702.0
# N6          1296.0   9337.0   1736.0      2.0   4353.0   3057.0   1974.0
# N7          3473.0  12257.0  12510.0   5889.0      1.0   5759.0   6285.0
# N8          1441.0   9708.0   5670.0   3818.0   2821.0    264.0   5435.0
# P5A         2673.0   8860.0   9520.0   2659.0   9521.0   7969.0      NaN
# P6A         3093.0  10604.0   4045.0   4449.0   6648.0   7340.0   4380.0
# P7A         2242.0   8978.0   6526.0   2867.0   7401.0   4493.0   6688.0
# P8A         2800.0  11804.0   6325.0   4970.0   3727.0  11174.0  10628.0
# AN3         5653.0  22592.0  19968.0  11521.0  16107.0  17835.0  13046.0
# AN35        2632.0  15023.0  10444.0   8650.0  10802.0   8466.0   6614.0
# ...

# %%
trp_df.columns
# Out:
# Index(['N1', 'N2', 'N5', 'N6', 'N7', 'N8', 'P5A', 'P6A', 'P7A', 'P8A', 'AN3',
#        'AN35', 'AN4', 'BN3', 'BN35', 'BN4', 'Jerala_P1', 'Jerala_P2',
#        'Jerala_P3', 'Jerala_P4', 'Jerala_P5', 'Jerala_P6', 'Jerala_P7',
#        'Jerala_P8', 'Jerala_P9', 'Jerala_P10', 'Jerala_P11', 'Jerala_P12'],
#       dtype='object')

# %%
AN_BN_list = ['AN3', 'AN35', 'AN4', 'BN3', 'BN35', 'BN4']

# %%
AN_BN_trp_df = trp_df.loc[AN_BN_list][AN_BN_list]

# %%
AN_BN_trp_df
# Out:
#             AN3     AN35      AN4      BN3     BN35      BN4
# Binder
# AN3      2166.0  24139.0  20633.0  15522.0  26331.0  22009.0
# AN35    11618.0   2401.0  12294.0  14040.0  16654.0   9915.0
# AN4     18294.0  17003.0    153.0  12303.0  16448.0  11726.0
# BN3     19953.0  15084.0  13403.0   1323.0  16123.0  26328.0
# BN35    36591.0  30704.0  20582.0  29288.0  20508.0  35968.0
# BN4     20162.0  19695.0   8641.0  11374.0  25738.0    116.0

# %% [markdown]
# ## TRP reads heatmap

# %%
plt.figure(figsize=(5, 4.0), dpi=100)


result = sns.heatmap(AN_BN_trp_df, cmap=cmap)

ax = result.axes

plt.xlabel('Activation domain', size = 12)
plt.ylabel('Binding domain', size = 12)

#for i in range(int(0.5*len(trp_df))):
#    rect = patches.Rectangle((1+2*i,2*i),1,1,linewidth=2,edgecolor='yellow',facecolor='none')
#    ax.add_patch(rect)
#    rect = patches.Rectangle((2*i,1+2*i),1,1,linewidth=2,edgecolor='yellow',facecolor='none')
#    ax.add_patch(rect)
# Out:
# Text(33.22222222222222, 0.5, 'Binding domain')

# %% [markdown]
# ## HIS 1mM 3-AT sample (output - after selecting for interaction)

# %%
his_1mM_3AT_df = pd.read_csv('L68-HIS-Reads-NO-PUMAs.csv', index_col=0)

# %%
his_1mM_3AT_df.shape
# Out:
# (28, 28)

# %%
his_1mM_3AT_df
# Out:
#                  N1        N2        N5        N6        N7        N8  \
# Binder
# N1            187.0  106936.0   58368.0   29231.0   39578.0   65446.0
# N2          77317.0    1978.0     891.0     706.0     584.0     607.0
# N5            339.0    1053.0     252.0  102019.0    1107.0     777.0
# N6            231.0  107295.0   47795.0      17.0    1020.0     468.0
# N7            377.0    6179.0    1449.0    6645.0       NaN  268528.0
# N8            231.0    1838.0     442.0     554.0  142539.0      22.0
# P5A           553.0    1176.0    3111.0   74455.0    1079.0     585.0
# P6A           691.0     896.0  178054.0     367.0     789.0     875.0
# P7A           308.0    2689.0    1561.0     193.0     717.0  212699.0
# P8A           503.0   12107.0     615.0     370.0  157743.0     831.0
# AN3           764.0    2367.0    1707.0    1179.0    2005.0    1248.0
# AN35          336.0    1266.0    1662.0    3661.0    1038.0     851.0
# ...

# %%
AN_BN_his_df = his_1mM_3AT_df.loc[AN_BN_list][AN_BN_list]

# %%
AN_BN_his_df
# Out:
#             AN3     AN35       AN4      BN3      BN35       BN4
# Binder
# AN3       110.0   1865.0    1844.0   1091.0    1972.0    1789.0
# AN35      817.0    187.0    2721.0    873.0   10781.0  103092.0
# AN4     10804.0   8211.0     147.0  15099.0  131652.0  338694.0
# BN3      1058.0    939.0    1023.0     30.0    1150.0    1995.0
# BN35     2190.0  29688.0  242635.0   1937.0    1304.0    2789.0
# BN4      1301.0  47024.0  276438.0    569.0    2200.0       6.0

# %%
plt.figure(figsize=(5, 4.0), dpi=100)


result = sns.heatmap(AN_BN_his_df, cmap=cmap)

ax = result.axes

plt.xlabel('Activation domain', size = 12)
plt.ylabel('Binding domain', size = 12)
# Out:
# Text(33.22222222222222, 0.5, 'Binding domain')

# %% [markdown]
# ## Enrichment dataframes

# %%
lin_1mM_3AT_df = pd.read_csv('L68-Lin-Enrichment-NO-PUMAs.csv', index_col=0)

# %%
lin_1mM_3AT_df.shape
# Out:
# (28, 28)

# %%
lin_1mM_3AT_df
# Out:
#                    N1         N2         N5         N6         N7         N8  \
# Binder
# N1           8.434910  50.021537  27.289369  23.054664  21.923801  22.926330
# N2          42.728958   2.699759   0.077501   0.082095   0.080370   0.079197
# N5           0.147097   0.113798   0.203672  49.889548   0.152544   0.101756
# N6           0.168836  10.885046  26.078996   8.051505   0.221957   0.145014
# N7           0.102824   0.477521   0.109716   1.068837        NaN  44.167277
# N8           0.151847   0.179339   0.073841   0.137446  47.861769   0.078936
# P5A          0.195968   0.125728   0.309543  26.523672   0.107349   0.069536
# P6A          0.211620   0.080038  41.695706   0.078138   0.112420   0.112920
# P7A          0.130129   0.283707   0.226576   0.063766   0.091767  44.842225
# P8A          0.170164   0.971551   0.092103   0.070519  40.091179   0.070445
# AN3          0.128018   0.099243   0.080976   0.096935   0.117912   0.066283
# ...

# %%
log_1mM_3AT_df = pd.read_csv('L68-Log-Enrichment-NO-PUMAs.csv', index_col=0)

# %%
log_1mM_3AT_df.shape
# Out:
# (28, 28)

# %%
log_1mM_3AT_df
# Out:
#                    N1         N2         N5         N6         N7         N8  \
# Binder
# N1           8.434910  50.021537  27.289369  23.054664  21.923801  22.926330
# N2          42.728958   2.699759   0.077501   0.082095   0.080370   0.079197
# N5           0.147097   0.113798   0.203672  49.889548   0.152544   0.101756
# N6           0.168836  10.885046  26.078996   8.051505   0.221957   0.145014
# N7           0.102824   0.477521   0.109716   1.068837        NaN  44.167277
# N8           0.151847   0.179339   0.073841   0.137446  47.861769   0.078936
# P5A          0.195968   0.125728   0.309543  26.523672   0.107349   0.069536
# P6A          0.211620   0.080038  41.695706   0.078138   0.112420   0.112920
# P7A          0.130129   0.283707   0.226576   0.063766   0.091767  44.842225
# P8A          0.170164   0.971551   0.092103   0.070519  40.091179   0.070445
# AN3          0.128018   0.099243   0.080976   0.096935   0.117912   0.066283
# ...

# %%
AN_BN_lin_df = lin_1mM_3AT_df.loc[AN_BN_list][AN_BN_list]

# %%
AN_BN_lin_df
# Out:
#              AN3      AN35        AN4       BN3      BN35        BN4
# Binder
# AN3     0.048105  0.073184   0.084656  0.066579  0.070941   0.076996
# AN35    0.066611  0.073775   0.209649  0.058899  0.613195   9.848960
# AN4     0.559415  0.457434   0.910089  1.162506  7.581803  27.359978
# BN3     0.050227  0.058967   0.072299  0.021479  0.067563   0.071777
# BN35    0.056693  0.915892  11.166678  0.062647  0.060230   0.073450
# BN4     0.061123  2.261631  30.303435  0.047387  0.080967   0.048995

# %%
AN_BN_log_df = log_1mM_3AT_df.loc[AN_BN_list][AN_BN_list]

# %%
AN_BN_log_df
# Out:
#              AN3      AN35        AN4       BN3      BN35        BN4
# Binder
# AN3     0.048105  0.073184   0.084656  0.066579  0.070941   0.076996
# AN35    0.066611  0.073775   0.209649  0.058899  0.613195   9.848960
# AN4     0.559415  0.457434   0.910089  1.162506  7.581803  27.359978
# BN3     0.050227  0.058967   0.072299  0.021479  0.067563   0.071777
# BN35    0.056693  0.915892  11.166678  0.062647  0.060230   0.073450
# BN4     0.061123  2.261631  30.303435  0.047387  0.080967   0.048995

# %% [markdown]
# ## Actually make it log (erroneously haven't been log yet)

# %%
AN_BN_log_df = np.log(AN_BN_log_df)

# %%
AN_BN_log_df
# Out:
#              AN3      AN35       AN4       BN3      BN35       BN4
# Binder
# AN3    -3.034364 -2.614775 -2.469162 -2.709371 -2.645906 -2.564002
# AN35   -2.708879 -2.606739 -1.562319 -2.831937 -0.489072  2.287366
# AN4    -0.580864 -0.782122 -0.094213  0.150578  2.025751  3.309081
# BN3    -2.991206 -2.830782 -2.626946 -3.840667 -2.694692 -2.634196
# BN35   -2.870108 -0.087857  2.412934 -2.770245 -2.809586 -2.611154
# BN4    -2.794874  0.816086  3.411261 -3.049412 -2.513718 -3.016038

# %% [markdown]
# ## Linear Enrichment Heatmap

# %%
plt.figure(figsize=(5.0, 4.0), dpi=100)


result = sns.heatmap(AN_BN_lin_df, cmap=cmap)

ax = result.axes

plt.xlabel('Activation domain', size = 12)
plt.ylabel('Binding domain', size = 12)

#for i in range(int(0.5*len(trp_df))):
#    rect = patches.Rectangle((1+2*i,2*i),1,1,linewidth=2,edgecolor='yellow',facecolor='none')
#    ax.add_patch(rect)
#    rect = patches.Rectangle((2*i,1+2*i),1,1,linewidth=2,edgecolor='yellow',facecolor='none')
#    ax.add_patch(rect)
# Out:
# Text(33.22222222222222, 0.5, 'Binding domain')

# %%
plt.figure(figsize=(5.0, 4.0), dpi=100)


result = sns.heatmap(AN_BN_log_df, cmap=cmap, vmin=-4.5, vmax=4.5)

ax = result.axes

plt.xlabel('Activation domain', size = 12)
plt.ylabel('Binding domain', size = 12)
# Out:
# Text(33.22222222222222, 0.5, 'Binding domain')

# %%
plt.figure(figsize=(3.7, 3.0), dpi=100)


result = sns.heatmap( AN_BN_log_df, cmap=cmap, mask = np.triu(np.ones_like(AN_BN_log_df)), vmin=-4.5, vmax=4.5 )

ax = result.axes

plt.xlabel('Activation domain', size = 12)
plt.ylabel('Binding domain', size = 12)
# Out:
# Text(16.97222222222222, 0.5, 'Binding domain')

# %%
plt.figure(figsize=(3.7, 3.0), dpi=100)


result = sns.heatmap( AN_BN_log_df, cmap=cmap, mask = np.tril(np.ones_like(AN_BN_log_df)), vmin=-4.5, vmax=4.5 )

ax = result.axes

plt.xlabel('Activation domain', size = 12)
plt.ylabel('Binding domain', size = 12)
# Out:
# Text(16.97222222222222, 0.5, 'Binding domain')

# %% [markdown]
# # Symmetry of the heatmap matrix

# %%
v_up, v_up_log, v_low, v_low_log = [], [], [], []

threshold = 20


for i in range(AN_BN_trp_df.shape[0]):
    for j in range(i+1, AN_BN_trp_df.shape[0]):
        
        trp_count_up  = AN_BN_trp_df.values[i][j]
        trp_count_low = AN_BN_trp_df.values[j][i]
        
        val_up  = AN_BN_his_df.values[i][j]
        val_low = AN_BN_his_df.values[j][i]

        if trp_count_up > threshold and trp_count_low > threshold and ~np.isnan(val_up) and ~np.isnan(val_low):

            v_up.append(val_up/trp_count_up)
            v_low.append(val_low/trp_count_low)

            v_up_log.append(math.log(val_up/trp_count_up))
            v_low_log.append(math.log(val_low/trp_count_low))

# %%
len(v_up)
# Out:
# 15

# %% [markdown]
# ## Upper and lower sub-matrix correlation

# %%
stats.pearsonr(v_up, v_low)[0]**2
# Out:
# 0.9130616594040316

# %%
stats.pearsonr(v_up_log, v_low_log)[0]**2
# Out:
# 0.7849052117846131

# %%
plt.figure(figsize=(5.0, 5.0), dpi=100)

#plt.xlim([50, 5000])
#plt.ylim([50, 5000])

plt.xlabel("Upper triangle", size=16)
plt.ylabel("Lower triangle", size=16)

plt.scatter(v_up, v_low)

# %%
plt.figure(figsize=(3.0, 3.0), dpi=100)

#plt.xlim([50, 5000])
#plt.ylim([50, 5000])

#plt.xlabel("Upper triangle", size=16)
#plt.ylabel("Lower triangle", size=16)

plt.scatter(v_up_log, v_low_log)
