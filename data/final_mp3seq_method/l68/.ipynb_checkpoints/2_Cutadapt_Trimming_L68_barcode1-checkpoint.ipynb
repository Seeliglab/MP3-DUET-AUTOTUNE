# %% [markdown]
#  Cutadapt:
#
#  http://cutadapt.readthedocs.io/en/stable/guide.html

# %%
import os
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
untrimmed_seqs_path = '../../Yeast2HybridData/NextSeq-2022-01-10-L68/Untrimmed/'
trimmed_seqs_path = '../../Yeast2HybridData/NextSeq-2022-01-10-L68/Trimmed/'

# %%
if not os.path.exists(untrimmed_seqs_path):
    os.makedirs(untrimmed_seqs_path)
    os.makedirs(trimmed_seqs_path)

# %% [markdown]
# ## Remove adaptors

# %% [markdown]
# #### list of fastq filenames

# %%
#files = [filename for filename in os.listdir(untrimmed_seqs_path) if filename[-6:] == '.fastq']
files = [filename for filename in os.listdir(untrimmed_seqs_path) if filename[-3:] == '.gz']
files = sorted(files)

# %%
files
# Out:
# ['L68_HIS_S2_R1_001.fastq.gz', 'L68_TRP_S1_R1_001.fastq.gz']

# %% [markdown]
# ### Define sequences surrounding the binders and the barcodes

# %%
# This version is for 71/237bp read1/read2

barcode1_prefix = "CGGGGCGGGGTTATTACGACAT"
barcode1_suffix = "CCTCCAGACAGCGTTCCGTTA"

# %% [markdown]
# ### Indexes

# %%
files_dict = {}

for f in files:
    
    files_dict[f] = [barcode1_prefix, barcode1_suffix]

# %%
files_dict
# Out:
# {'L68_HIS_S2_R1_001.fastq.gz': ['CGGGGCGGGGTTATTACGACAT',
#   'CCTCCAGACAGCGTTCCGTTA'],
#  'L68_TRP_S1_R1_001.fastq.gz': ['CGGGGCGGGGTTATTACGACAT',
#   'CCTCCAGACAGCGTTCCGTTA']}

# %% [markdown]
# ### loop through and trim each fastq file with cutadapt

# %%
for path, affix in files_dict.items():
    # input and output paths
    untrimmed = untrimmed_seqs_path + path
    trimmed = trimmed_seqs_path + path
    
    
    # just trim off the 5' end
    if len(affix) == 1:
        suffix = affix[0]
        #!~/.local/bin/cutadapt -g {suffix} -m 17 -M 23 -e 0.1 -o {trimmed} {untrimmed}
        # !cutadapt -g {suffix} -m 7 -M 23 -e 0.1 -o {trimmed} {untrimmed}
    
    # trim off before and after the barcode
    else:
        prefix = affix[0]
        suffix = affix[1]
        #!~/.local/bin/cutadapt -g {prefix}...{suffix} -m 17 -M 23 -e 0.1 -o {trimmed} {untrimmed}
        # !cutadapt -g {prefix}...{suffix} -m 17 -M 23 -e 0.1 -o {trimmed} {untrimmed}
        
# -g marks linked adaptors, neither of which are 'anchored'
# -m 5 -- this parameter tells cutadapt to throw away reads that have yield a sequence <5 nucleotides long.
# If you don't do this, you sometimes end up with empty rows, which fucks up later processing using pandas -- pandas'
# read_csv function automatically ignores empty rows, messing up the spacing (the names are kept) and making
# life difficult.
# Out:
# This is cutadapt 1.18 with Python 3.6.9
# Command line parameters: -g CGGGGCGGGGTTATTACGACAT...CCTCCAGACAGCGTTCCGTTA -m 17 -M 23 -e 0.1 -o ../../Yeast2HybridData/NextSeq-2022-01-10-L68/Trimmed/L68_HIS_S2_R1_001.fastq.gz ../../Yeast2HybridData/NextSeq-2022-01-10-L68/Untrimmed/L68_HIS_S2_R1_001.fastq.gz
# Processing reads on 1 core in single-end mode ...
# Finished in 213.92 s (26 us/read; 2.35 M reads/minute).
#
# === Summary ===
#
# Total reads processed:               8,375,754
# Reads with adapters:                 8,339,898 (99.6%)
# Reads that were too short:               8,966 (0.1%)
# Reads that were too long:               44,765 (0.5%)
# Reads written (passing filters):     8,322,023 (99.4%)
#
# Total basepairs processed: 2,052,059,730 bp
# Total written (filtered):    166,431,486 bp (8.1%)
#
# === Adapter 2 ===
#
# Sequence: CGGGGCGGGGTTATTACGACAT...CCTCCAGACAGCGTTCCGTTA; Type: linked; Length: 22+21; 5' trimmed: 8339898 times; 3' trimmed: 8339898 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-21 bp: 2
#
# Overview of removed sequences at 5' end
# length	count	expect	max.err	error counts
# 3	146	130871.2	0	146
# 4	60	32717.8	0	60
# 5	10	8179.4	0	10
# 6	1	2044.9	0	1
# 7	2	511.2	0	2
# 22	1	0.0	2	0 1
# 43	1	0.0	2	1
# 51	1	0.0	2	0 0 1
# 52	3	0.0	2	3
# 53	1	0.0	2	1
# 55	1	0.0	2	1
# 56	3	0.0	2	2 0 1
# 57	19	0.0	2	17 2
# 58	12	0.0	2	11 0 1
# 59	17	0.0	2	17
# 60	27	0.0	2	23 1 3
# 61	57	0.0	2	54 2 1
# 62	61	0.0	2	57 2 2
# 63	122	0.0	2	114 4 4
# 64	105	0.0	2	95 4 6
# 65	141	0.0	2	132 3 6
# 66	196	0.0	2	162 4 30
# 67	783	0.0	2	218 7 558
# 68	70524	0.0	2	323 56 70145
# 69	868	0.0	2	668 24 176
# 70	1096	0.0	2	1047 34 15
# 71	3858	0.0	2	3484 162 212
# 72	82446	0.0	2	68067 11482 2897
# 73	8149144	0.0	2	8010398 126241 12505
# 74	26855	0.0	2	19307 6879 669
# 75	297	0.0	2	186 32 79
# 76	79	0.0	2	78 0 1
# 77	80	0.0	2	76 2 2
# 78	2679	0.0	2	2633 39 7
# 79	28	0.0	2	28
# 80	30	0.0	2	30
# 81	25	0.0	2	25
# 82	8	0.0	2	8
# 83	22	0.0	2	22
# 84	5	0.0	2	5
# 85	7	0.0	2	7
# 86	7	0.0	2	7
# 87	8	0.0	2	8
# 88	4	0.0	2	3 0 1
# 89	3	0.0	2	3
# 90	7	0.0	2	6 1
# 91	2	0.0	2	2
# 92	6	0.0	2	4 0 2
# 93	3	0.0	2	3
# 94	4	0.0	2	4
# 95	3	0.0	2	3
# 96	4	0.0	2	4
# 97	4	0.0	2	3 0 1
# 98	3	0.0	2	3
# 99	3	0.0	2	3
# 100	1	0.0	2	1
# 101	4	0.0	2	3 1
# 102	3	0.0	2	3
# 107	1	0.0	2	1
# 109	3	0.0	2	3
# 110	1	0.0	2	1
# 112	1	0.0	2	1
# 114	1	0.0	2	1
# 123	1	0.0	2	1
#
#
# Overview of removed sequences at 3' end
# length	count	expect	max.err	error counts
# 3	1	130871.2	0	1
# 69	28	0.0	2	25 2 1
# 72	4	0.0	2	0 2 2
# 73	11	0.0	2	5 4 2
# 74	3	0.0	2	2 1
# 96	1	0.0	2	1
# 98	12	0.0	2	11 1
# 102	1	0.0	2	1
# 111	1	0.0	2	1
# 113	1	0.0	2	1
# 115	1	0.0	2	1
# 116	3	0.0	2	3
# 118	2	0.0	2	2
# 123	3	0.0	2	1 2
# 124	4	0.0	2	4
# 125	1	0.0	2	1
# 126	3	0.0	2	3
# 127	3	0.0	2	3
# 128	4	0.0	2	4
# 129	4	0.0	2	4
# 130	42	0.0	2	40 2
# 131	6	0.0	2	5 1
# 132	23	0.0	2	22 1
# 133	8420	0.0	2	8018 317 85
# 134	78	0.0	2	68 10
# 135	11	0.0	2	9 2
# 136	12	0.0	2	10 2
# 137	14	0.0	2	12 2
# 138	36	0.0	2	26 7 3
# 139	9	0.0	2	6 2 1
# 140	18	0.0	2	7 1 10
# 141	9	0.0	2	6 0 3
# 142	23	0.0	2	22 1
# 143	9	0.0	2	8 0 1
# 144	29	0.0	2	23 3 3
# 145	33	0.0	2	27 4 2
# 146	30	0.0	2	30
# 147	2680	0.0	2	2582 76 22
# 148	79	0.0	2	75 3 1
# 149	84	0.0	2	82 1 1
# 150	216	0.0	2	205 10 1
# 151	25827	0.0	2	24604 1017 206
# 152	8125542	0.0	2	7873223 220562 31757
# 153	89458	0.0	2	81694 6987 777
# 154	3954	0.0	2	3773 154 27
# 155	1258	0.0	2	1149 93 16
# 156	9616	0.0	2	9167 367 82
# 157	70629	0.0	2	67546 2710 373
# 158	818	0.0	2	781 29 8
# 159	197	0.0	2	181 11 5
# 160	145	0.0	2	136 7 2
# 161	105	0.0	2	99 6
# 162	126	0.0	2	115 9 2
# 163	62	0.0	2	56 4 2
# 164	117	0.0	2	110 5 2
# 165	25	0.0	2	24 1
# 166	17	0.0	2	17
# 167	11	0.0	2	11
# 168	28	0.0	2	24 2 2
# 169	3	0.0	2	3
# 170	1	0.0	2	0 1
# 172	1	0.0	2	1
# 173	3	0.0	2	3
# 174	1	0.0	2	1
# 182	1	0.0	2	1
# 203	1	0.0	2	1
#
# This is cutadapt 1.18 with Python 3.6.9
# Command line parameters: -g CGGGGCGGGGTTATTACGACAT...CCTCCAGACAGCGTTCCGTTA -m 17 -M 23 -e 0.1 -o ../../Yeast2HybridData/NextSeq-2022-01-10-L68/Trimmed/L68_TRP_S1_R1_001.fastq.gz ../../Yeast2HybridData/NextSeq-2022-01-10-L68/Untrimmed/L68_TRP_S1_R1_001.fastq.gz
# Processing reads on 1 core in single-end mode ...
# Finished in 203.38 s (26 us/read; 2.32 M reads/minute).
#
# === Summary ===
#
# Total reads processed:               7,872,442
# Reads with adapters:                 7,832,446 (99.5%)
# Reads that were too short:               1,824 (0.0%)
# Reads that were too long:               43,597 (0.6%)
# Reads written (passing filters):     7,827,021 (99.4%)
#
# Total basepairs processed: 1,928,748,290 bp
# Total written (filtered):    156,534,492 bp (8.1%)
#
# === Adapter 2 ===
#
# Sequence: CGGGGCGGGGTTATTACGACAT...CCTCCAGACAGCGTTCCGTTA; Type: linked; Length: 22+21; 5' trimmed: 7832446 times; 3' trimmed: 7832446 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20-21 bp: 2
#
# Overview of removed sequences at 5' end
# length	count	expect	max.err	error counts
# 3	133	123006.9	0	133
# 4	47	30751.7	0	47
# 5	9	7687.9	0	9
# 6	3	1922.0	0	3
# 10	1	7.5	1	0 1
# 51	1	0.0	2	1
# 52	2	0.0	2	2
# 54	3	0.0	2	3
# 55	66	0.0	2	66
# 56	7	0.0	2	6 1
# 57	18	0.0	2	17 0 1
# 58	15	0.0	2	15
# 59	32	0.0	2	32
# 60	21	0.0	2	17 4
# 61	401	0.0	2	314 86 1
# 62	52	0.0	2	49 3
# 63	280	0.0	2	269 10 1
# 64	83	0.0	2	81 2
# 65	105	0.0	2	101 3 1
# 66	323	0.0	2	309 11 3
# 67	244	0.0	2	224 10 10
# 68	1332	0.0	2	317 16 999
# 69	852	0.0	2	829 17 6
# 70	1356	0.0	2	1305 37 14
# 71	4708	0.0	2	3836 236 636
# 72	87144	0.0	2	67977 16236 2931
# 73	7702863	0.0	2	7571762 117917 13184
# 74	30587	0.0	2	23894 5779 914
# 75	854	0.0	2	297 17 540
# 76	87	0.0	2	76 6 5
# 77	49	0.0	2	48 1
# 78	278	0.0	2	271 6 1
# 79	12	0.0	2	12
# 80	10	0.0	2	10
# 81	10	0.0	2	10
# 82	20	0.0	2	18 1 1
# 83	341	0.0	2	329 11 1
# 84	9	0.0	2	9
# 85	3	0.0	2	3
# 86	5	0.0	2	5
# 87	5	0.0	2	3 0 2
# 88	5	0.0	2	5
# 89	2	0.0	2	2
# 90	2	0.0	2	2
# 91	2	0.0	2	2
# 92	7	0.0	2	6 0 1
# 93	2	0.0	2	2
# 94	4	0.0	2	4
# 95	5	0.0	2	5
# 97	1	0.0	2	1
# 98	1	0.0	2	1
# 99	3	0.0	2	3
# 100	2	0.0	2	2
# 101	1	0.0	2	1
# 102	3	0.0	2	3
# 103	4	0.0	2	4
# 104	6	0.0	2	6
# 107	3	0.0	2	3
# 109	1	0.0	2	1
# 118	1	0.0	2	1
# 121	1	0.0	2	1
# 122	1	0.0	2	1
# 123	1	0.0	2	1
# 151	2	0.0	2	2
# 152	5	0.0	2	5
# 156	8	0.0	2	8
# 179	2	0.0	2	2
#
#
# Overview of removed sequences at 3' end
# length	count	expect	max.err	error counts
# 3	4	123006.9	0	4
# 4	2	30751.7	0	2
# 46	7	0.0	2	2 4 1
# 68	2	0.0	2	2
# 69	534	0.0	2	431 74 29
# 70	2	0.0	2	1 1
# 72	28	0.0	2	18 5 5
# 73	162	0.0	2	100 38 24
# 74	47	0.0	2	35 6 6
# 93	42	0.0	2	35 5 2
# 94	1	0.0	2	1
# 97	3	0.0	2	3
# 98	71	0.0	2	66 5
# 99	1	0.0	2	1
# 102	1	0.0	2	1
# 103	1	0.0	2	1
# 104	1	0.0	2	1
# 107	1	0.0	2	1
# 116	1	0.0	2	1
# 118	3	0.0	2	2 1
# 121	6	0.0	2	5 1
# 122	4	0.0	2	4
# 123	3	0.0	2	3
# 124	1	0.0	2	1
# 125	2	0.0	2	2
# 126	3	0.0	2	3
# 127	1	0.0	2	1
# 128	1	0.0	2	1
# 130	15	0.0	2	14 0 1
# 131	8	0.0	2	8
# 132	11	0.0	2	10 0 1
# 133	1977	0.0	2	1874 87 16
# 134	25	0.0	2	21 4
# 135	6	0.0	2	3 3
# 136	14	0.0	2	9 5
# 137	18	0.0	2	16 2
# 138	469	0.0	2	437 22 10
# 139	8	0.0	2	8
# 140	8	0.0	2	3 1 4
# 141	11	0.0	2	8 3
# 142	342	0.0	2	324 14 4
# 143	20	0.0	2	17 3
# 144	12	0.0	2	9 2 1
# 145	11	0.0	2	10 0 1
# 146	12	0.0	2	9 3
# 147	278	0.0	2	265 13
# 148	49	0.0	2	47 2
# 149	111	0.0	2	102 7 2
# 150	330	0.0	2	307 20 3
# 151	31479	0.0	2	29831 1364 284
# 152	7694767	0.0	2	7436510 224336 33921
# 153	88657	0.0	2	84160 3753 744
# 154	5292	0.0	2	5026 220 46
# 155	1914	0.0	2	1777 103 34
# 156	1173	0.0	2	1107 55 11
# 157	1692	0.0	2	1592 86 14
# 158	720	0.0	2	668 32 20
# 159	341	0.0	2	317 12 12
# 160	106	0.0	2	99 5 2
# 161	83	0.0	2	79 4
# 162	326	0.0	2	313 12 1
# 163	52	0.0	2	52
# 164	840	0.0	2	805 28 7
# 165	22	0.0	2	20 1 1
# 166	32	0.0	2	31 1
# 167	15	0.0	2	15
# 168	183	0.0	2	175 8
# 169	8	0.0	2	8
# 170	68	0.0	2	65 3
# 171	3	0.0	2	3
# 173	2	0.0	2	2
# 174	1	0.0	2	1
