# %%
import os
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
import math

# %%
# %matplotlib inline

# %% [markdown]
# # TRP

# %%
L44_trp = pd.DataFrame.from_csv('L44_TRP_table.csv')

# %%
L44_trp.shape
# Out:
# (337, 337)

# %%
L44_trp.head(2)
# Out:
#                    2CDP06  A_HT_DHD_100_swap  A_HT_DHD_10_swap  \
# Binder1
# 2CDP06              897.0              173.0             314.0
# A_HT_DHD_100_swap   633.0               70.0             221.0
#
#                    A_HT_DHD_11_swap  A_HT_DHD_12_swap  A_HT_DHD_13_swap  \
# Binder1
# 2CDP06                        610.0             346.0              82.0
# A_HT_DHD_100_swap             374.0              75.0              65.0
#
#                    A_HT_DHD_14_swap  A_HT_DHD_15_swap  A_HT_DHD_16_swap  \
# Binder1
# 2CDP06                         90.0            1083.0             541.0
# A_HT_DHD_100_swap             192.0             504.0             151.0
#
#                    A_HT_DHD_17_swap      ...        mALb8_A  mALb8_B  \
# Binder1                                  ...
# 2CDP06                        527.0      ...          904.0    253.0
# A_HT_DHD_100_swap             156.0      ...          306.0     51.0
#
#                    mALb8_cutT1_A  mALb8_cutT1_B  mALb8_cutT2_A  mALb8_cutT2_B  \
# Binder1
# 2CDP06                     256.0          509.0          228.0          385.0
# A_HT_DHD_100_swap          243.0          391.0          260.0          203.0
#
#                    mALb8_cutT3_A  mALb8_cutT3_B  mALb8_cutT4_A  mALb8_cutT4_B
# Binder1
# 2CDP06                     481.0          262.0          334.0          448.0
# A_HT_DHD_100_swap          212.0          151.0          107.0          215.0
#
# [2 rows x 337 columns]

# %%
L44_trp.columns
# Out:
# Index(['2CDP06', 'A_HT_DHD_100_swap', 'A_HT_DHD_10_swap', 'A_HT_DHD_11_swap',
#        'A_HT_DHD_12_swap', 'A_HT_DHD_13_swap', 'A_HT_DHD_14_swap',
#        'A_HT_DHD_15_swap', 'A_HT_DHD_16_swap', 'A_HT_DHD_17_swap',
#        ...
#        'mALb8_A', 'mALb8_B', 'mALb8_cutT1_A', 'mALb8_cutT1_B', 'mALb8_cutT2_A',
#        'mALb8_cutT2_B', 'mALb8_cutT3_A', 'mALb8_cutT3_B', 'mALb8_cutT4_A',
#        'mALb8_cutT4_B'],
#       dtype='object', length=337)

# %% [markdown]
# ## Remove '_swap' from binders names

# %%
modified_index = []

for i in range(L44_trp.shape[0]):
    modified_index.append(L44_trp.index[i].split('_swap')[0])

# %%
len(modified_index)
# Out:
# 337

# %%
modified_index
# Out:
# ['2CDP06',
#  'A_HT_DHD_100',
#  'A_HT_DHD_10',
#  'A_HT_DHD_11',
#  'A_HT_DHD_12',
#  'A_HT_DHD_13',
#  'A_HT_DHD_14',
#  'A_HT_DHD_15',
#  'A_HT_DHD_16',
#  'A_HT_DHD_17',
#  'A_HT_DHD_18',
#  'A_HT_DHD_19',
#  'A_HT_DHD_1',
#  'A_HT_DHD_20',
#  'A_HT_DHD_21',
#  'A_HT_DHD_22',
#  'A_HT_DHD_23',
#  'A_HT_DHD_24',
#  'A_HT_DHD_25',
#  'A_HT_DHD_26',
#  'A_HT_DHD_27',
#  'A_HT_DHD_28',
#  'A_HT_DHD_29',
#  'A_HT_DHD_2',
#  'A_HT_DHD_30',
#  'A_HT_DHD_31',
#  'A_HT_DHD_32',
#  'A_HT_DHD_33',
#  'A_HT_DHD_34',
#  'A_HT_DHD_35',
#  'A_HT_DHD_36',
#  'A_HT_DHD_37',
#  'A_HT_DHD_38',
#  'A_HT_DHD_39',
#  'A_HT_DHD_3',
#  'A_HT_DHD_40',
#  'A_HT_DHD_41',
#  'A_HT_DHD_42',
#  'A_HT_DHD_43',
#  'A_HT_DHD_44',
#  'A_HT_DHD_45',
#  'A_HT_DHD_46',
#  'A_HT_DHD_47',
#  'A_HT_DHD_48',
#  'A_HT_DHD_49',
#  'A_HT_DHD_4',
#  'A_HT_DHD_50',
#  'A_HT_DHD_51',
#  'A_HT_DHD_52',
#  'A_HT_DHD_53',
#  'A_HT_DHD_54',
#  'A_HT_DHD_55',
#  'A_HT_DHD_56',
#  'A_HT_DHD_57',
#  'A_HT_DHD_58',
#  'A_HT_DHD_59',
#  'A_HT_DHD_5',
#  'A_HT_DHD_60',
#  'A_HT_DHD_61',
#  'A_HT_DHD_62',
#  'A_HT_DHD_63',
#  'A_HT_DHD_64',
#  'A_HT_DHD_65',
#  'A_HT_DHD_66',
#  'A_HT_DHD_67',
#  'A_HT_DHD_68',
#  'A_HT_DHD_69',
#  'A_HT_DHD_6',
#  'A_HT_DHD_70',
#  'A_HT_DHD_71',
#  'A_HT_DHD_72',
#  'A_HT_DHD_73',
#  'A_HT_DHD_74',
#  'A_HT_DHD_75',
#  'A_HT_DHD_76',
#  'A_HT_DHD_77',
#  'A_HT_DHD_78',
#  'A_HT_DHD_79',
#  'A_HT_DHD_7',
#  'A_HT_DHD_80',
#  'A_HT_DHD_81',
#  'A_HT_DHD_82',
#  'A_HT_DHD_83',
#  'A_HT_DHD_84',
#  'A_HT_DHD_85',
#  'A_HT_DHD_86',
#  'A_HT_DHD_87',
#  'A_HT_DHD_88',
#  'A_HT_DHD_89',
#  'A_HT_DHD_8',
#  'A_HT_DHD_90',
#  'A_HT_DHD_91',
#  'A_HT_DHD_92',
#  'A_HT_DHD_93',
#  'A_HT_DHD_94',
#  'A_HT_DHD_95',
#  'A_HT_DHD_96',
#  'A_HT_DHD_97',
#  'A_HT_DHD_98',
#  'A_HT_DHD_99',
#  'A_HT_DHD_9',
#  'A_ZCON_13',
#  'A_ZCON_150',
#  'A_ZCON_154',
#  'A_ZCON_155',
#  'A_ZCON_15_re_loop',
#  'A_ZCON_162',
#  'A_ZCON_37_3',
#  'A_ZCON_37',
#  'A_ZCON_6',
#  'BCDP01',
#  'BECM01',
#  'B_HT_DHD_100',
#  'B_HT_DHD_10',
#  'B_HT_DHD_11',
#  'B_HT_DHD_12',
#  'B_HT_DHD_13',
#  'B_HT_DHD_14',
#  'B_HT_DHD_15',
#  'B_HT_DHD_16',
#  'B_HT_DHD_17',
#  'B_HT_DHD_18',
#  'B_HT_DHD_19',
#  'B_HT_DHD_1',
#  'B_HT_DHD_20',
#  'B_HT_DHD_21',
#  'B_HT_DHD_22',
#  'B_HT_DHD_23',
#  'B_HT_DHD_24',
#  'B_HT_DHD_25',
#  'B_HT_DHD_26',
#  'B_HT_DHD_27',
#  'B_HT_DHD_28',
#  'B_HT_DHD_29',
#  'B_HT_DHD_2',
#  'B_HT_DHD_30',
#  'B_HT_DHD_31',
#  'B_HT_DHD_32',
#  'B_HT_DHD_33',
#  'B_HT_DHD_34',
#  'B_HT_DHD_35',
#  'B_HT_DHD_36',
#  'B_HT_DHD_37',
#  'B_HT_DHD_38',
#  'B_HT_DHD_39',
#  'B_HT_DHD_3',
#  'B_HT_DHD_40',
#  'B_HT_DHD_41',
#  'B_HT_DHD_42',
#  'B_HT_DHD_43',
#  'B_HT_DHD_44',
#  'B_HT_DHD_45',
#  'B_HT_DHD_46',
#  'B_HT_DHD_47',
#  'B_HT_DHD_48',
#  'B_HT_DHD_49',
#  'B_HT_DHD_4',
#  'B_HT_DHD_50',
#  'B_HT_DHD_51',
#  'B_HT_DHD_52',
#  'B_HT_DHD_53',
#  'B_HT_DHD_54',
#  'B_HT_DHD_55',
#  'B_HT_DHD_56',
#  'B_HT_DHD_57',
#  'B_HT_DHD_58',
#  'B_HT_DHD_59',
#  'B_HT_DHD_5',
#  'B_HT_DHD_60',
#  'B_HT_DHD_61',
#  'B_HT_DHD_62',
#  'B_HT_DHD_63',
#  'B_HT_DHD_64',
#  'B_HT_DHD_65',
#  'B_HT_DHD_66',
#  'B_HT_DHD_67',
#  'B_HT_DHD_68',
#  'B_HT_DHD_69',
#  'B_HT_DHD_6',
#  'B_HT_DHD_70',
#  'B_HT_DHD_71',
#  'B_HT_DHD_72',
#  'B_HT_DHD_73',
#  'B_HT_DHD_74',
#  'B_HT_DHD_75',
#  'B_HT_DHD_76',
#  'B_HT_DHD_77',
#  'B_HT_DHD_78',
#  'B_HT_DHD_79',
#  'B_HT_DHD_7',
#  'B_HT_DHD_80',
#  'B_HT_DHD_81',
#  'B_HT_DHD_82',
#  'B_HT_DHD_83',
#  'B_HT_DHD_84',
#  'B_HT_DHD_85',
#  'B_HT_DHD_86',
#  'B_HT_DHD_87',
#  'B_HT_DHD_88',
#  'B_HT_DHD_89',
#  'B_HT_DHD_8',
#  'B_HT_DHD_90',
#  'B_HT_DHD_91',
#  'B_HT_DHD_92',
#  'B_HT_DHD_93',
#  'B_HT_DHD_94',
#  'B_HT_DHD_95',
#  'B_HT_DHD_96',
#  'B_HT_DHD_97',
#  'B_HT_DHD_98',
#  'B_HT_DHD_99',
#  'B_HT_DHD_9',
#  'B_ZCON_13',
#  'B_ZCON_150',
#  'B_ZCON_154',
#  'B_ZCON_155',
#  'B_ZCON_15_re_loop',
#  'B_ZCON_162',
#  'B_ZCON_37_3',
#  'B_ZCON_37',
#  'B_ZCON_6',
#  'Bcl-2',
#  'Bcl-B',
#  'Bcl-w',
#  'Bcl-xL',
#  'Bfl-1',
#  'DHDr2_00_A',
#  'DHDr2_00_B',
#  'DHDr2_01_A',
#  'DHDr2_01_B',
#  'DHDr2_02_A',
#  'DHDr2_02_B',
#  'DHDr2_03_A',
#  'DHDr2_03_B',
#  'DHDr2_04_A',
#  'DHDr2_04_B',
#  'DHDr2_05_A',
#  'DHDr2_05_B',
#  'DHDr2_06_A',
#  'DHDr2_06_B',
#  'DHDr2_07_A',
#  'DHDr2_07_B',
#  'DHDr2_08_A',
#  'DHDr2_08_B',
#  'DHDr2_09_A',
#  'DHDr2_09_B',
#  'DHDr2_10_A',
#  'DHDr2_10_B',
#  'DHDr2_11_A',
#  'DHDr2_11_B',
#  'DHDr2_12_A',
#  'DHDr2_12_B',
#  'DHDr2_13_A',
#  'DHDr2_13_B',
#  'DHDr2_14_A',
#  'DHDr2_14_B',
#  'DHDr2_15_A',
#  'DHDr2_15_B',
#  'DHDr2_16_A',
#  'DHDr2_16_B',
#  'DHDr2_17_A',
#  'DHDr2_17_B',
#  'DHDr2_18_A',
#  'DHDr2_18_B',
#  'DHDr2_19_A',
#  'DHDr2_19_B',
#  'DHDr2_20_A',
#  'DHDr2_20_B',
#  'FECM04',
#  'Mcl1[151-321]',
#  'XCDP07',
#  'ZCON_150_LL_A',
#  'ZCON_150_LL_B',
#  'ZCON_150_resurf_A',
#  'ZCON_150_resurf_B',
#  'ZCON_152_A',
#  'ZCON_152_B',
#  'ZCON_152_T2_A',
#  'ZCON_152_T2_B',
#  'ZCON_152_T4_A',
#  'ZCON_152_T4_B',
#  'ZCON_154_LL_A',
#  'ZCON_154_LL_B',
#  'ZCON_154_resurf_A',
#  'ZCON_154_resurf_B',
#  'ZCON_155_LL_A',
#  'ZCON_155_LL_B',
#  'ZCON_155_cutT2_A',
#  'ZCON_155_cutT2_B',
#  'ZCON_155_cutT4_A',
#  'ZCON_155_cutT4_B',
#  'ZCON_155_cutT5_A',
#  'ZCON_155_cutT5_B',
#  'ZCON_155_resurf_A',
#  'ZCON_155_resurf_B',
#  'ZCON_15_re_loop_LL_A',
#  'ZCON_15_re_loop_LL_B',
#  'ZCON_15_re_loop_resurf_A',
#  'ZCON_15_re_loop_resurf_B',
#  'ZCON_2_CC_A',
#  'ZCON_2_CC_B',
#  'ZCON_2_CC_resurf_A',
#  'ZCON_2_CC_resurf_B',
#  'ZCON_2_CC_resurf_cutT2_A',
#  'ZCON_2_CC_resurf_cutT2_B',
#  'ZCON_2_CC_resurf_cutT4_A',
#  'ZCON_2_CC_resurf_cutT4_B',
#  'ZCON_2_CC_resurf_cutT6_A',
#  'ZCON_2_CC_resurf_cutT6_B',
#  'ZCON_37_LL_A',
#  'ZCON_37_LL_B',
#  'ZCON_37_resurf_A',
#  'ZCON_37_resurf_B',
#  'ZCON_VR_2_A',
#  'ZCON_VR_2_B',
#  'ZCON_VR_2_cutT2_A',
#  'ZCON_VR_2_cutT2_B',
#  'ZCON_VR_2_cutT4_A',
#  'ZCON_VR_2_cutT4_B',
#  'ZCON_VR_2_cutT6_A',
#  'ZCON_VR_2_cutT6_B',
#  'ZCON_VR_2_resurf_A',
#  'ZCON_VR_2_resurf_B',
#  'alphaBCL2',
#  'alphaBCLB',
#  'alphaBFL1',
#  'alphaMCL1',
#  'mALb8_A',
#  'mALb8_B',
#  'mALb8_cutT1_A',
#  'mALb8_cutT1_B',
#  'mALb8_cutT2_A',
#  'mALb8_cutT2_B',
#  'mALb8_cutT3_A',
#  'mALb8_cutT3_B',
#  'mALb8_cutT4_A',
#  'mALb8_cutT4_B']

# %%
modified_index[:2]
# Out:
# ['2CDP06', 'A_HT_DHD_100']

# %%
L44_trp = L44_trp.set_index(pd.Index(modified_index))

# %%
L44_trp.head(2)
# Out:
#               2CDP06  A_HT_DHD_100_swap  A_HT_DHD_10_swap  A_HT_DHD_11_swap  \
# 2CDP06         897.0              173.0             314.0             610.0
# A_HT_DHD_100   633.0               70.0             221.0             374.0
#
#               A_HT_DHD_12_swap  A_HT_DHD_13_swap  A_HT_DHD_14_swap  \
# 2CDP06                   346.0              82.0              90.0
# A_HT_DHD_100              75.0              65.0             192.0
#
#               A_HT_DHD_15_swap  A_HT_DHD_16_swap  A_HT_DHD_17_swap  \
# 2CDP06                  1083.0             541.0             527.0
# A_HT_DHD_100             504.0             151.0             156.0
#
#                   ...        mALb8_A  mALb8_B  mALb8_cutT1_A  mALb8_cutT1_B  \
# 2CDP06            ...          904.0    253.0          256.0          509.0
# A_HT_DHD_100      ...          306.0     51.0          243.0          391.0
#
#               mALb8_cutT2_A  mALb8_cutT2_B  mALb8_cutT3_A  mALb8_cutT3_B  \
# 2CDP06                228.0          385.0          481.0          262.0
# A_HT_DHD_100          260.0          203.0          212.0          151.0
#
#               mALb8_cutT4_A  mALb8_cutT4_B
# 2CDP06                334.0          448.0
# A_HT_DHD_100          107.0          215.0
#
# [2 rows x 337 columns]

# %%
modified_cols = []

for col in L44_trp.columns:
    modified_cols.append(col.split('_swap')[0])

# %%
modified_cols[:5]
# Out:
# ['2CDP06', 'A_HT_DHD_100', 'A_HT_DHD_10', 'A_HT_DHD_11', 'A_HT_DHD_12']

# %%
L44_trp.columns = modified_cols

# %%
L44_trp.head(2)
# Out:
#               2CDP06  A_HT_DHD_100  A_HT_DHD_10  A_HT_DHD_11  A_HT_DHD_12  \
# 2CDP06         897.0         173.0        314.0        610.0        346.0
# A_HT_DHD_100   633.0          70.0        221.0        374.0         75.0
#
#               A_HT_DHD_13  A_HT_DHD_14  A_HT_DHD_15  A_HT_DHD_16  A_HT_DHD_17  \
# 2CDP06               82.0         90.0       1083.0        541.0        527.0
# A_HT_DHD_100         65.0        192.0        504.0        151.0        156.0
#
#                   ...        mALb8_A  mALb8_B  mALb8_cutT1_A  mALb8_cutT1_B  \
# 2CDP06            ...          904.0    253.0          256.0          509.0
# A_HT_DHD_100      ...          306.0     51.0          243.0          391.0
#
#               mALb8_cutT2_A  mALb8_cutT2_B  mALb8_cutT3_A  mALb8_cutT3_B  \
# 2CDP06                228.0          385.0          481.0          262.0
# A_HT_DHD_100          260.0          203.0          212.0          151.0
#
#               mALb8_cutT4_A  mALb8_cutT4_B
# 2CDP06                334.0          448.0
# A_HT_DHD_100          107.0          215.0
#
# [2 rows x 337 columns]

# %% [markdown]
# ## Create ordered list

# %%
binders_list = []

for binder in L44_trp.columns:
    if 'A_' in binder:
        binders_list.append(binder)
        binders_list.append('B' + binder[1:])
    elif '_A' in binder:
        binders_list.append(binder)
        binders_list.append(binder[:-1] + 'B')
        
for binder in L44_trp.columns:
    if 'A_' not in binder and '_A' not in binder and 'B_' not in binder and '_B' not in binder:
        binders_list.append(binder)

# %%
len(binders_list)
# Out:
# 337

# %%
binders_list[:4]
# Out:
# ['A_HT_DHD_100', 'B_HT_DHD_100', 'A_HT_DHD_10', 'B_HT_DHD_10']

# %%
L44_trp.reindex(binders_list)[binders_list].head(4)
# Out:
#               A_HT_DHD_100  B_HT_DHD_100  A_HT_DHD_10  B_HT_DHD_10  \
# A_HT_DHD_100          70.0         396.0        221.0        194.0
# B_HT_DHD_100         236.0         526.0        200.0        505.0
# A_HT_DHD_10           54.0         492.0         59.0        264.0
# B_HT_DHD_10          266.0         580.0         88.0        497.0
#
#               A_HT_DHD_11  B_HT_DHD_11  A_HT_DHD_12  B_HT_DHD_12  A_HT_DHD_13  \
# A_HT_DHD_100        374.0        490.0         75.0        201.0         65.0
# B_HT_DHD_100        312.0        516.0        110.0        193.0        317.0
# A_HT_DHD_10          79.0        202.0         85.0        276.0         43.0
# B_HT_DHD_10         621.0        596.0         29.0        202.0        140.0
#
#               B_HT_DHD_13    ...      Bcl-w  Bcl-xL   Bfl-1  FECM04  \
# A_HT_DHD_100        228.0    ...      161.0   295.0   530.0   516.0
# B_HT_DHD_100        205.0    ...       72.0   380.0   791.0   523.0
# A_HT_DHD_10         239.0    ...       70.0   212.0   533.0   629.0
# B_HT_DHD_10         531.0    ...      116.0   409.0  1039.0  1025.0
#
#               Mcl1[151-321]  XCDP07  alphaBCL2  alphaBCLB  alphaBFL1  \
# A_HT_DHD_100         1021.0   143.0      360.0      815.0      324.0
# B_HT_DHD_100          481.0   241.0      216.0     1191.0      805.0
# A_HT_DHD_10           717.0    69.0       54.0      583.0      661.0
# B_HT_DHD_10          1796.0   281.0      353.0     1275.0      869.0
#
#               alphaMCL1
# A_HT_DHD_100      827.0
# B_HT_DHD_100      979.0
# A_HT_DHD_10       517.0
# B_HT_DHD_10      1583.0
#
# [4 rows x 337 columns]

# %%
list(L44_trp.reindex(binders_list)[binders_list])
# Out:
# ['A_HT_DHD_100',
#  'B_HT_DHD_100',
#  'A_HT_DHD_10',
#  'B_HT_DHD_10',
#  'A_HT_DHD_11',
#  'B_HT_DHD_11',
#  'A_HT_DHD_12',
#  'B_HT_DHD_12',
#  'A_HT_DHD_13',
#  'B_HT_DHD_13',
#  'A_HT_DHD_14',
#  'B_HT_DHD_14',
#  'A_HT_DHD_15',
#  'B_HT_DHD_15',
#  'A_HT_DHD_16',
#  'B_HT_DHD_16',
#  'A_HT_DHD_17',
#  'B_HT_DHD_17',
#  'A_HT_DHD_18',
#  'B_HT_DHD_18',
#  'A_HT_DHD_19',
#  'B_HT_DHD_19',
#  'A_HT_DHD_1',
#  'B_HT_DHD_1',
#  'A_HT_DHD_20',
#  'B_HT_DHD_20',
#  'A_HT_DHD_21',
#  'B_HT_DHD_21',
#  'A_HT_DHD_22',
#  'B_HT_DHD_22',
#  'A_HT_DHD_23',
#  'B_HT_DHD_23',
#  'A_HT_DHD_24',
#  'B_HT_DHD_24',
#  'A_HT_DHD_25',
#  'B_HT_DHD_25',
#  'A_HT_DHD_26',
#  'B_HT_DHD_26',
#  'A_HT_DHD_27',
#  'B_HT_DHD_27',
#  'A_HT_DHD_28',
#  'B_HT_DHD_28',
#  'A_HT_DHD_29',
#  'B_HT_DHD_29',
#  'A_HT_DHD_2',
#  'B_HT_DHD_2',
#  'A_HT_DHD_30',
#  'B_HT_DHD_30',
#  'A_HT_DHD_31',
#  'B_HT_DHD_31',
#  'A_HT_DHD_32',
#  'B_HT_DHD_32',
#  'A_HT_DHD_33',
#  'B_HT_DHD_33',
#  'A_HT_DHD_34',
#  'B_HT_DHD_34',
#  'A_HT_DHD_35',
#  'B_HT_DHD_35',
#  'A_HT_DHD_36',
#  'B_HT_DHD_36',
#  'A_HT_DHD_37',
#  'B_HT_DHD_37',
#  'A_HT_DHD_38',
#  'B_HT_DHD_38',
#  'A_HT_DHD_39',
#  'B_HT_DHD_39',
#  'A_HT_DHD_3',
#  'B_HT_DHD_3',
#  'A_HT_DHD_40',
#  'B_HT_DHD_40',
#  'A_HT_DHD_41',
#  'B_HT_DHD_41',
#  'A_HT_DHD_42',
#  'B_HT_DHD_42',
#  'A_HT_DHD_43',
#  'B_HT_DHD_43',
#  'A_HT_DHD_44',
#  'B_HT_DHD_44',
#  'A_HT_DHD_45',
#  'B_HT_DHD_45',
#  'A_HT_DHD_46',
#  'B_HT_DHD_46',
#  'A_HT_DHD_47',
#  'B_HT_DHD_47',
#  'A_HT_DHD_48',
#  'B_HT_DHD_48',
#  'A_HT_DHD_49',
#  'B_HT_DHD_49',
#  'A_HT_DHD_4',
#  'B_HT_DHD_4',
#  'A_HT_DHD_50',
#  'B_HT_DHD_50',
#  'A_HT_DHD_51',
#  'B_HT_DHD_51',
#  'A_HT_DHD_52',
#  'B_HT_DHD_52',
#  'A_HT_DHD_53',
#  'B_HT_DHD_53',
#  'A_HT_DHD_54',
#  'B_HT_DHD_54',
#  'A_HT_DHD_55',
#  'B_HT_DHD_55',
#  'A_HT_DHD_56',
#  'B_HT_DHD_56',
#  'A_HT_DHD_57',
#  'B_HT_DHD_57',
#  'A_HT_DHD_58',
#  'B_HT_DHD_58',
#  'A_HT_DHD_59',
#  'B_HT_DHD_59',
#  'A_HT_DHD_5',
#  'B_HT_DHD_5',
#  'A_HT_DHD_60',
#  'B_HT_DHD_60',
#  'A_HT_DHD_61',
#  'B_HT_DHD_61',
#  'A_HT_DHD_62',
#  'B_HT_DHD_62',
#  'A_HT_DHD_63',
#  'B_HT_DHD_63',
#  'A_HT_DHD_64',
#  'B_HT_DHD_64',
#  'A_HT_DHD_65',
#  'B_HT_DHD_65',
#  'A_HT_DHD_66',
#  'B_HT_DHD_66',
#  'A_HT_DHD_67',
#  'B_HT_DHD_67',
#  'A_HT_DHD_68',
#  'B_HT_DHD_68',
#  'A_HT_DHD_69',
#  'B_HT_DHD_69',
#  'A_HT_DHD_6',
#  'B_HT_DHD_6',
#  'A_HT_DHD_70',
#  'B_HT_DHD_70',
#  'A_HT_DHD_71',
#  'B_HT_DHD_71',
#  'A_HT_DHD_72',
#  'B_HT_DHD_72',
#  'A_HT_DHD_73',
#  'B_HT_DHD_73',
#  'A_HT_DHD_74',
#  'B_HT_DHD_74',
#  'A_HT_DHD_75',
#  'B_HT_DHD_75',
#  'A_HT_DHD_76',
#  'B_HT_DHD_76',
#  'A_HT_DHD_77',
#  'B_HT_DHD_77',
#  'A_HT_DHD_78',
#  'B_HT_DHD_78',
#  'A_HT_DHD_79',
#  'B_HT_DHD_79',
#  'A_HT_DHD_7',
#  'B_HT_DHD_7',
#  'A_HT_DHD_80',
#  'B_HT_DHD_80',
#  'A_HT_DHD_81',
#  'B_HT_DHD_81',
#  'A_HT_DHD_82',
#  'B_HT_DHD_82',
#  'A_HT_DHD_83',
#  'B_HT_DHD_83',
#  'A_HT_DHD_84',
#  'B_HT_DHD_84',
#  'A_HT_DHD_85',
#  'B_HT_DHD_85',
#  'A_HT_DHD_86',
#  'B_HT_DHD_86',
#  'A_HT_DHD_87',
#  'B_HT_DHD_87',
#  'A_HT_DHD_88',
#  'B_HT_DHD_88',
#  'A_HT_DHD_89',
#  'B_HT_DHD_89',
#  'A_HT_DHD_8',
#  'B_HT_DHD_8',
#  'A_HT_DHD_90',
#  'B_HT_DHD_90',
#  'A_HT_DHD_91',
#  'B_HT_DHD_91',
#  'A_HT_DHD_92',
#  'B_HT_DHD_92',
#  'A_HT_DHD_93',
#  'B_HT_DHD_93',
#  'A_HT_DHD_94',
#  'B_HT_DHD_94',
#  'A_HT_DHD_95',
#  'B_HT_DHD_95',
#  'A_HT_DHD_96',
#  'B_HT_DHD_96',
#  'A_HT_DHD_97',
#  'B_HT_DHD_97',
#  'A_HT_DHD_98',
#  'B_HT_DHD_98',
#  'A_HT_DHD_99',
#  'B_HT_DHD_99',
#  'A_HT_DHD_9',
#  'B_HT_DHD_9',
#  'A_ZCON_13',
#  'B_ZCON_13',
#  'A_ZCON_150',
#  'B_ZCON_150',
#  'A_ZCON_154',
#  'B_ZCON_154',
#  'A_ZCON_155',
#  'B_ZCON_155',
#  'A_ZCON_15_re_loop',
#  'B_ZCON_15_re_loop',
#  'A_ZCON_162',
#  'B_ZCON_162',
#  'A_ZCON_37_3',
#  'B_ZCON_37_3',
#  'A_ZCON_37',
#  'B_ZCON_37',
#  'A_ZCON_6',
#  'B_ZCON_6',
#  'DHDr2_00_A',
#  'DHDr2_00_B',
#  'DHDr2_01_A',
#  'DHDr2_01_B',
#  'DHDr2_02_A',
#  'DHDr2_02_B',
#  'DHDr2_03_A',
#  'DHDr2_03_B',
#  'DHDr2_04_A',
#  'DHDr2_04_B',
#  'DHDr2_05_A',
#  'DHDr2_05_B',
#  'DHDr2_06_A',
#  'DHDr2_06_B',
#  'DHDr2_07_A',
#  'DHDr2_07_B',
#  'DHDr2_08_A',
#  'DHDr2_08_B',
#  'DHDr2_09_A',
#  'DHDr2_09_B',
#  'DHDr2_10_A',
#  'DHDr2_10_B',
#  'DHDr2_11_A',
#  'DHDr2_11_B',
#  'DHDr2_12_A',
#  'DHDr2_12_B',
#  'DHDr2_13_A',
#  'DHDr2_13_B',
#  'DHDr2_14_A',
#  'DHDr2_14_B',
#  'DHDr2_15_A',
#  'DHDr2_15_B',
#  'DHDr2_16_A',
#  'DHDr2_16_B',
#  'DHDr2_17_A',
#  'DHDr2_17_B',
#  'DHDr2_18_A',
#  'DHDr2_18_B',
#  'DHDr2_19_A',
#  'DHDr2_19_B',
#  'DHDr2_20_A',
#  'DHDr2_20_B',
#  'ZCON_150_LL_A',
#  'ZCON_150_LL_B',
#  'ZCON_150_resurf_A',
#  'ZCON_150_resurf_B',
#  'ZCON_152_A',
#  'ZCON_152_B',
#  'ZCON_152_T2_A',
#  'ZCON_152_T2_B',
#  'ZCON_152_T4_A',
#  'ZCON_152_T4_B',
#  'ZCON_154_LL_A',
#  'ZCON_154_LL_B',
#  'ZCON_154_resurf_A',
#  'ZCON_154_resurf_B',
#  'ZCON_155_LL_A',
#  'ZCON_155_LL_B',
#  'ZCON_155_cutT2_A',
#  'ZCON_155_cutT2_B',
#  'ZCON_155_cutT4_A',
#  'ZCON_155_cutT4_B',
#  'ZCON_155_cutT5_A',
#  'ZCON_155_cutT5_B',
#  'ZCON_155_resurf_A',
#  'ZCON_155_resurf_B',
#  'ZCON_15_re_loop_LL_A',
#  'ZCON_15_re_loop_LL_B',
#  'ZCON_15_re_loop_resurf_A',
#  'ZCON_15_re_loop_resurf_B',
#  'ZCON_2_CC_A',
#  'ZCON_2_CC_B',
#  'ZCON_2_CC_resurf_A',
#  'ZCON_2_CC_resurf_B',
#  'ZCON_2_CC_resurf_cutT2_A',
#  'ZCON_2_CC_resurf_cutT2_B',
#  'ZCON_2_CC_resurf_cutT4_A',
#  'ZCON_2_CC_resurf_cutT4_B',
#  'ZCON_2_CC_resurf_cutT6_A',
#  'ZCON_2_CC_resurf_cutT6_B',
#  'ZCON_37_LL_A',
#  'ZCON_37_LL_B',
#  'ZCON_37_resurf_A',
#  'ZCON_37_resurf_B',
#  'ZCON_VR_2_A',
#  'ZCON_VR_2_B',
#  'ZCON_VR_2_cutT2_A',
#  'ZCON_VR_2_cutT2_B',
#  'ZCON_VR_2_cutT4_A',
#  'ZCON_VR_2_cutT4_B',
#  'ZCON_VR_2_cutT6_A',
#  'ZCON_VR_2_cutT6_B',
#  'ZCON_VR_2_resurf_A',
#  'ZCON_VR_2_resurf_B',
#  'mALb8_A',
#  'mALb8_B',
#  'mALb8_cutT1_A',
#  'mALb8_cutT1_B',
#  'mALb8_cutT2_A',
#  'mALb8_cutT2_B',
#  'mALb8_cutT3_A',
#  'mALb8_cutT3_B',
#  'mALb8_cutT4_A',
#  'mALb8_cutT4_B',
#  '2CDP06',
#  'BCDP01',
#  'BECM01',
#  'Bcl-2',
#  'Bcl-B',
#  'Bcl-w',
#  'Bcl-xL',
#  'Bfl-1',
#  'FECM04',
#  'Mcl1[151-321]',
#  'XCDP07',
#  'alphaBCL2',
#  'alphaBCLB',
#  'alphaBFL1',
#  'alphaMCL1']

# %%
L44_trp.reindex(binders_list)[binders_list].to_csv('L44_TRP_sorted_table.csv')

# %% [markdown]
# # HIS1_1mM_3AT

# %%
L44_his_1mM_3AT = pd.DataFrame.from_csv('L44_HIS_1mM_3AT_table.csv')

# %%
L44_his_1mM_3AT.shape
# Out:
# (337, 337)

# %%
L44_his_1mM_3AT.head(2)
# Out:
#                     2CDP06  A_HT_DHD_100_swap  A_HT_DHD_10_swap  \
# Binder1
# 2CDP06             13097.0                5.0              28.0
# A_HT_DHD_100_swap     57.0               13.0             161.0
#
#                    A_HT_DHD_11_swap  A_HT_DHD_12_swap  A_HT_DHD_13_swap  \
# Binder1
# 2CDP06                        115.0              81.0            1335.0
# A_HT_DHD_100_swap              43.0              35.0               7.0
#
#                    A_HT_DHD_14_swap  A_HT_DHD_15_swap  A_HT_DHD_16_swap  \
# Binder1
# 2CDP06                          1.0              52.0              77.0
# A_HT_DHD_100_swap               2.0              92.0              24.0
#
#                    A_HT_DHD_17_swap      ...        mALb8_A  mALb8_B  \
# Binder1                                  ...
# 2CDP06                      18682.0      ...           63.0     28.0
# A_HT_DHD_100_swap              27.0      ...           81.0     19.0
#
#                    mALb8_cutT1_A  mALb8_cutT1_B  mALb8_cutT2_A  mALb8_cutT2_B  \
# Binder1
# 2CDP06                      29.0         8087.0           42.0           14.0
# A_HT_DHD_100_swap           20.0           21.0          182.0            1.0
#
#                    mALb8_cutT3_A  mALb8_cutT3_B  mALb8_cutT4_A  mALb8_cutT4_B
# Binder1
# 2CDP06                     105.0        32216.0           54.0           96.0
# A_HT_DHD_100_swap           36.0           56.0           25.0           10.0
#
# [2 rows x 337 columns]

# %% [markdown]
# ## Remove '_swap' from binders names

# %%
modified_index = []

for i in range(L44_his_1mM_3AT.shape[0]):
    modified_index.append(L44_his_1mM_3AT.index[i].split('_swap')[0])

# %%
len(modified_index)
# Out:
# 337

# %%
modified_index[:2]
# Out:
# ['2CDP06', 'A_HT_DHD_100']

# %%
L44_his_1mM_3AT = L44_his_1mM_3AT.set_index(pd.Index(modified_index))

# %%
L44_his_1mM_3AT.head(2)
# Out:
#                2CDP06  A_HT_DHD_100_swap  A_HT_DHD_10_swap  A_HT_DHD_11_swap  \
# 2CDP06        13097.0                5.0              28.0             115.0
# A_HT_DHD_100     57.0               13.0             161.0              43.0
#
#               A_HT_DHD_12_swap  A_HT_DHD_13_swap  A_HT_DHD_14_swap  \
# 2CDP06                    81.0            1335.0               1.0
# A_HT_DHD_100              35.0               7.0               2.0
#
#               A_HT_DHD_15_swap  A_HT_DHD_16_swap  A_HT_DHD_17_swap  \
# 2CDP06                    52.0              77.0           18682.0
# A_HT_DHD_100              92.0              24.0              27.0
#
#                   ...        mALb8_A  mALb8_B  mALb8_cutT1_A  mALb8_cutT1_B  \
# 2CDP06            ...           63.0     28.0           29.0         8087.0
# A_HT_DHD_100      ...           81.0     19.0           20.0           21.0
#
#               mALb8_cutT2_A  mALb8_cutT2_B  mALb8_cutT3_A  mALb8_cutT3_B  \
# 2CDP06                 42.0           14.0          105.0        32216.0
# A_HT_DHD_100          182.0            1.0           36.0           56.0
#
#               mALb8_cutT4_A  mALb8_cutT4_B
# 2CDP06                 54.0           96.0
# A_HT_DHD_100           25.0           10.0
#
# [2 rows x 337 columns]

# %%
modified_cols = []

for col in L44_his_1mM_3AT.columns:
    modified_cols.append(col.split('_swap')[0])

# %%
modified_cols[:5]
# Out:
# ['2CDP06', 'A_HT_DHD_100', 'A_HT_DHD_10', 'A_HT_DHD_11', 'A_HT_DHD_12']

# %%
L44_his_1mM_3AT.columns = modified_cols

# %%
L44_his_1mM_3AT.head(2)
# Out:
#                2CDP06  A_HT_DHD_100  A_HT_DHD_10  A_HT_DHD_11  A_HT_DHD_12  \
# 2CDP06        13097.0           5.0         28.0        115.0         81.0
# A_HT_DHD_100     57.0          13.0        161.0         43.0         35.0
#
#               A_HT_DHD_13  A_HT_DHD_14  A_HT_DHD_15  A_HT_DHD_16  A_HT_DHD_17  \
# 2CDP06             1335.0          1.0         52.0         77.0      18682.0
# A_HT_DHD_100          7.0          2.0         92.0         24.0         27.0
#
#                   ...        mALb8_A  mALb8_B  mALb8_cutT1_A  mALb8_cutT1_B  \
# 2CDP06            ...           63.0     28.0           29.0         8087.0
# A_HT_DHD_100      ...           81.0     19.0           20.0           21.0
#
#               mALb8_cutT2_A  mALb8_cutT2_B  mALb8_cutT3_A  mALb8_cutT3_B  \
# 2CDP06                 42.0           14.0          105.0        32216.0
# A_HT_DHD_100          182.0            1.0           36.0           56.0
#
#               mALb8_cutT4_A  mALb8_cutT4_B
# 2CDP06                 54.0           96.0
# A_HT_DHD_100           25.0           10.0
#
# [2 rows x 337 columns]

# %% [markdown]
# ## Create ordered list

# %%
binders_list = []

for binder in L44_his_1mM_3AT.columns:
    if 'A_' in binder:
        binders_list.append(binder)
        binders_list.append('B' + binder[1:])
    elif '_A' in binder:
        binders_list.append(binder)
        binders_list.append(binder[:-1] + 'B')

        
for binder in L44_his_1mM_3AT.columns:
    if 'A_' not in binder and '_A' not in binder and 'B_' not in binder and '_B' not in binder:
        binders_list.append(binder)

# %%
binders_list[:4]
# Out:
# ['A_HT_DHD_100', 'B_HT_DHD_100', 'A_HT_DHD_10', 'B_HT_DHD_10']

# %%
L44_his_1mM_3AT.reindex(binders_list)[binders_list].head(4)
# Out:
#               A_HT_DHD_100  B_HT_DHD_100  A_HT_DHD_10  B_HT_DHD_10  \
# A_HT_DHD_100          13.0         210.0        161.0         25.0
# B_HT_DHD_100          14.0          82.0         19.0        114.0
# A_HT_DHD_10            9.0        1465.0         25.0        129.0
# B_HT_DHD_10            4.0          91.0         32.0        179.0
#
#               A_HT_DHD_11  B_HT_DHD_11  A_HT_DHD_12  B_HT_DHD_12  A_HT_DHD_13  \
# A_HT_DHD_100         43.0         67.0         35.0          8.0          7.0
# B_HT_DHD_100       9969.0         86.0         28.0         34.0         25.0
# A_HT_DHD_10           3.0         34.0          1.0         40.0        491.0
# B_HT_DHD_10          95.0        163.0          NaN          6.0         30.0
#
#               B_HT_DHD_13    ...      Bcl-w  Bcl-xL  Bfl-1  FECM04  \
# A_HT_DHD_100         34.0    ...       28.0   198.0  122.0   401.0
# B_HT_DHD_100         74.0    ...       10.0    22.0  150.0    93.0
# A_HT_DHD_10         109.0    ...        1.0     9.0   22.0    11.0
# B_HT_DHD_10          72.0    ...       10.0    30.0   58.0  3169.0
#
#               Mcl1[151-321]  XCDP07  alphaBCL2  alphaBCLB  alphaBFL1  \
# A_HT_DHD_100          123.0    33.0       33.0      185.0       90.0
# B_HT_DHD_100           90.0    22.0       33.0      140.0       96.0
# A_HT_DHD_10            60.0     6.0        NaN       70.0       94.0
# B_HT_DHD_10           181.0    10.0       54.0      117.0       45.0
#
#               alphaMCL1
# A_HT_DHD_100       80.0
# B_HT_DHD_100      124.0
# A_HT_DHD_10        26.0
# B_HT_DHD_10       148.0
#
# [4 rows x 337 columns]

# %%
L44_his_1mM_3AT.reindex(binders_list)[binders_list].to_csv('L44_HIS_1mM_3AT_sorted_table.csv')
